# %% [markdown]
# <a href="https://colab.research.google.com/github/suneesh/noise-reduction-using-rnn/blob/master/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import datetime
# import scipy.signal as signal
# import scipy.io.wavfile as wav
# import scipy.io.wavfile as wav
import os, random, sys
# from pylab import plot,show, figure, imshow
# import matplotlib.pyplot as plt
import librosa.core as audio

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import TimeDistributed,Dense,LSTM,Input,Lambda,Dropout #,CuDNNLSTM, CuDNNGRU,,BatchNormalization,
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras import regularizers as reg
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import normalize, MinMaxScaler, MaxAbsScaler
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'

# %%
# !wget http://mirlab.org/dataset/public/MIR-1K.zip -p /content/Noise/MIR-1K.zip

# %%
# !git clone https://github.com/adityatb/noise-reduction-using-rnn.git
# Out:
# Cloning into 'noise-reduction-using-rnn'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Unpacking objects: 100% (70/70), done.

# %%
# ----------------------------------------------
# Function Defs
# ----------------------------------------------
def genStartVal(vLen,nLen):
    startVal = math.floor(abs(np.random.randn()*0.02*vLen))
    if startVal+vLen < nLen:
        return startVal
    else:
        #genStartVal(vLen,nLen)

def spectrumSequence(time_series_data,nfft,fs_):
    nFiles = len(time_series_data)
    sequence = []
    lengths = []
    for idx in range(nFiles):
        thisData = time_series_data[idx].T.squeeze()
        spectrum =  audio.stft(thisData,n_fft=nfft,hop_length=int(nfft/2),center=False)
        Mag = np.abs(spectrum).T
        sequence.append(Mag)
        lengths.append(len(Mag))
    return sequence,lengths
#
def pad_seq(allData,maxlen):
    paddedData = pad_sequences(allData,maxlen=maxlen,dtype='float32',value=0.0)
    return paddedData


def softMasking(y):
    input = y[0]
    y1_hat = y[1]
    y2_hat = y[2]
    s1,s2 = computeSoftMask(y1_hat,y2_hat)
    y1_tilde = np.multiply(s1,input)
    y2_tilde = np.multiply(s2,input)
    return [y1_tilde, y2_tilde]

def maskedOutShape(shape):
    shape_0 = list(shape[0])
    shape_1 = list(shape[1])
    return [tuple(shape_0),tuple(shape_1)]

def computeSoftMask(y1,y2):
    y1 = np.abs(y1)
    y2 = np.abs(y2)
    m1 = np.divide(y1,np.add(y1,y2))
    m2 = np.divide(y2,np.add(y1,y2))
    # m2 = 1 - m1
    return [m1,m2]
# ----------------------------------------------
# Out:
#   File "<ipython-input-19-842fbff712c9>", line 11
#     def spectrumSequence(time_series_data,nfft,fs_):
#                                                     ^
# IndentationError: expected an indented block

# %% [markdown]
# load

# %%
# ----------------------------------------------
# Dataset: MIR-1k
# Training and Validation sets are prepared automatically by Keras later.
# ----------------------------------------------

dataset	= os.getcwd()+"/data/MIR-1K/"
noisedataset  = os.getcwd()+"/Noise"
os.listdir(noisedataset)
os.listdir(dataset)
# Out:
# ['vocal-nonvocalLabel',
#  'PitchLabel',
#  'readme.txt',
#  'Wavfile',
#  'LyricsWav',
#  'Lyrics',
#  'UnvoicedFrameLabel',
#  'UndividedWavfile']

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New section

# %%
# ----------------------------------------------

# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------

# ----------------------------------------------
# Gather Data into Memory
# ----------------------------------------------

# Buffer training data to memory for faster execution:
for root,_,files in os.walk(dataset):
    files = sorted(files)



for root2,_,noises in os.walk(noisedataset):
    noises = sorted(noises)


mir_music = []
mir_voice = []


for idx,f in enumerate(files):
    if f.endswith(".wav"):
        data,srate = audio.load(os.path.join(root,f),sr=None,mono=False)
        music = data[0,:]
        voice = data[1,:]
        mir_music.append(music)
        mir_voice.append(voice)

# ----------------------------------------------
# Buffer Noise Files into Memory
# ----------------------------------------------
noisesVec = []

for idx,nf in enumerate(noises):
    if not nf.startswith('.') and nf.endswith(".wav"):
        data,_ = audio.load(os.path.join(root2,nf),sr=None,mono=False)
        noisesVec.append(data)

# %%
print(len(mir_voice))
# Out:
# 110

# %%
# ----------------------------------------------
# Add a random part of ach noise file to each voice
# ----------------------------------------------

noiseData = []
voiceData = []
noiseAddedData = []


for idx,thisNoise in enumerate(noisesVec):
    for each,thisVoice in enumerate(mir_voice):
        voiceLen = len(thisVoice)
        noiseLen = len(thisNoise)
        startVal = genStartVal(voiceLen,noiseLen)
        endVal = startVal+voiceLen
        noiseBit = normalize(thisNoise[startVal:endVal].reshape(1,-1),norm='max')
        voiceBit = normalize(thisVoice.reshape(1,-1),norm='max')
        noiseAdd = 0.5*np.add(voiceBit,noiseBit)
        voiceData.append(voiceBit)
        noiseData.append(noiseBit)
        noiseAddedData.append(noiseAdd)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-12-dbd5604f6f64> in <module>()
#      12         voiceLen = len(thisVoice)
#      13         noiseLen = len(thisNoise)
# ---> 14         startVal = genStartVal(voiceLen,noiseLen)
#      15         endVal = startVal+voiceLen
#      16         noiseBit = normalize(thisNoise[startVal:endVal].reshape(1,-1),norm='max')
#
# <ipython-input-2-3b713c096b72> in genStartVal(vLen, nLen)
#       7         return startVal
#       8     else:
# ----> 9         genStartVal(vLen,nLen)
#      10
#      11 def spectrumSequence(time_series_data,nfft,fs_):
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-3b713c096b72> in genStartVal(vLen, nLen)
#       7         return startVal
#       8     else:
# ----> 9         genStartVal(vLen,nLen)
#      10
#      11 def spectrumSequence(time_series_data,nfft,fs_):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
# ----------------------------------------------
# Shuffle so that same voices don't form consecutive data
# ----------------------------------------------


combinedDataFrames = list(zip(voiceData,noiseAddedData,noiseData))
random.shuffle(combinedDataFrames)
voiceData[:],noiseAddedData[:],noiseData[:] = zip(*combinedDataFrames)


# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------

# ----------------------------------------------
# Produce Spectra
# ----------------------------------------------


nfft = 1024
fs = srate #16000

x_data,l1  = spectrumSequence(noiseAddedData,nfft,fs)
y1_data,l2 = spectrumSequence(voiceData,nfft,fs)
y2_data,l3 = spectrumSequence(noiseData,nfft,fs)

assert len(x_data) == len(y1_data) == len(y2_data)

# ----------------------------------------------
# Normalize Spectra to the Input
# ----------------------------------------------

scaler1 = MaxAbsScaler(copy=False)
scaler2 = MinMaxScaler(feature_range=(0.0,1.0),copy=False)

for idx in range(len(x_data)):
    scaler1.fit_transform(x_data[idx])
    # scaler1.fit_transform(x_data[idx])
    scaler1.fit_transform(y1_data[idx])
    scaler1.fit_transform(y2_data[idx])
    # scaler2.fit(x_data[idx])
    scaler2.fit_transform(x_data[idx])
    scaler2.fit_transform(y1_data[idx])
    scaler2.fit_transform(y2_data[idx])

# plt.pcolormesh(x_data[0])
# plt.plot(x_data[0][1])
# show()

l1 = max(l1)
l2 = max(l2)
l3 = max(l3)
maxL = max(l1,l2,l3)

del mir_music, mir_voice, noisesVec, combinedDataFrames
#
train_x = pad_seq(x_data,maxL)
y1      = pad_seq(y1_data,maxL)
y2      = pad_seq(y2_data,maxL)


del x_data, y1_data,y2_data

# gc.collect()
# ----------------------------------------------
# Setup Model
# ----------------------------------------------
#
# # Model Parameters
batch_size = 10
learning_rate = 1e-5
decay_ = 1e-3
epochs = 200
n_units = 600 #int(2*nfft/1)

shape = train_x.shape[1:]
n_outs = train_x.shape[2] # Note: Not train_x.shape[1:], which returns shape for input_shape, instead of int.


# # CPU Version :: Functional API
regularizer = reg.l2(0.05)
input = Input(shape=shape)
# input_mask = Masking(mask_value=0.,input_shape=shape)(input)
hid1 = LSTM(n_units,return_sequences=True, activation='relu')(input)
dp1  = Dropout(0.2)(hid1)
hid2 = LSTM(n_units,return_sequences=True, activation='relu')(dp1)
dp2  = Dropout(0.2)(hid2)
hid3 = LSTM(n_units,return_sequences=True, activation='relu')(dp2)
y1_hat = TimeDistributed(Dense(train_x.shape[2], activation='softmax', input_shape=train_x.shape[1:]), name='y1_hat')(hid3)
y2_hat = TimeDistributed(Dense(train_x.shape[2], activation='softmax', input_shape=train_x.shape[1:]), name='y2_hat')(hid3)
out1,out2 = Lambda(softMasking,maskedOutShape,name='softMask')([input,y1_hat,y2_hat])

model = Model(inputs=input,outputs=[out1,out2])
model.summary()
#
#
opt = tf.keras.optimizers.Adam(lr=learning_rate, decay=decay_)
model.compile(loss='kullback_leibler_divergence',optimizer=opt, metrics=['acc','mse']) #kullback_leibler_divergence

curdir = os.getcwd()+"/logs/"

if not os.path.exists('Checkpoints'):
    os.makedirs('Checkpoints')

chkpoint_path = os.getcwd()+"/Checkpoints/ModelChkpoint_epoch{epoch:02d}_vLoss{val_loss:.2f}.hdf5"

tensorboard = TensorBoard(log_dir=curdir)

checkpt = ModelCheckpoint(filepath=chkpoint_path,monitor='val_softMask_acc',save_best_only=True,save_weights_only=False)
earlystop = EarlyStopping(monitor='val_softMask_acc', min_delta=1e-3, patience=10)
history = model.fit(train_x,[y1,y2],batch_size=batch_size,epochs=epochs,validation_split=0.1,callbacks=[tensorboard,checkpt,earlystop])

if not os.path.exists('Models'):
    os.makedirs('Models')

date_time = datetime.datetime.now()
model_path = os.getcwd()+f"/Models/Model_{date_time}.hdf5"
model.save(model_path)

# %%
# Out:
# --2022-01-11 05:39:42--  http://mirlab.org/dataset/public/MIR-1K.zip
# Resolving mirlab.org (mirlab.org)... 140.112.91.63
# Connecting to mirlab.org (mirlab.org)|140.112.91.63|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1022400042 (975M) [application/x-zip-compressed]
# Saving to: ‘mirlab.org/dataset/public/MIR-1K.zip’
#
# mirlab.org/dataset/ 100%[===================>] 975.04M  23.9MB/s    in 42s
#
# 2022-01-11 05:40:24 (23.3 MB/s) - ‘mirlab.org/dataset/public/MIR-1K.zip’ saved [1022400042/1022400042]
#
# /content/Noise: Scheme missing.
# FINISHED --2022-01-11 05:40:24--
# Total wall clock time: 42s
# Downloaded: 1 files, 975M in 42s (23.3 MB/s)

# %%
# !unzip mirlab.org/dataset/public/MIR-1K.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/MIR-1K/Lyrics/annar_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_2_08.txt
#   inflating: /content/data/MIR-1K/Lyrics/annar_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_02.txt
#   inflating: /content/data/MIR-1K/Lyrics/annar_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/annar_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/ariel_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_04.txt
#   inflating: /content/data/MIR-1K/Lyrics/bobon_1_05.txt
#   inflating: /content/data/MIR-1K/Lyrics/bobon_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_01.txt
#   inflating: /content/data/MIR-1K/Lyrics/bobon_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/bobon_5_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_4_01.txt
#   inflating: /content/data/MIR-1K/Lyrics/bug_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_07.txt
#   inflating: /content/data/MIR-1K/Lyrics/bug_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/bug_5_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_04.txt
#   inflating: /content/data/MIR-1K/Lyrics/davidson_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_3_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_4_02.txt
#   inflating: /content/data/MIR-1K/Lyrics/davidson_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_4_06.txt
#   inflating: /content/data/MIR-1K/Lyrics/davidson_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/davidson_5_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_1_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_2_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_03.txt
#   inflating: /content/data/MIR-1K/Lyrics/fdps_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/fdps_5_09.txt
#   inflating: /content/data/MIR-1K/Lyrics/geniusturtle_1_01.txt
#   inflating: /content/data/MIR-1K/Lyrics/geniusturtle_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_06.txt
#   inflating: /content/data/MIR-1K/Lyrics/geniusturtle_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_03.txt
#   inflating: /content/data/MIR-1K/Lyrics/geniusturtle_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_4_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_04.txt
#   inflating: /content/data/MIR-1K/Lyrics/geniusturtle_6_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_6_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_7_15.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/geniusturtle_8_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/heycat_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_1_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_07.txt
#   inflating: /content/data/MIR-1K/Lyrics/jmzen_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_2_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_3_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/jmzen_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_1_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_06.txt
#   inflating: /content/data/MIR-1K/Lyrics/Kenshin_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_2_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_05.txt
#   inflating: /content/data/MIR-1K/Lyrics/Kenshin_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_3_07.txt
#   inflating: /content/data/MIR-1K/Lyrics/Kenshin_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_4_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/Kenshin_5_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_4_03.txt
#   inflating: /content/data/MIR-1K/Lyrics/khair_4_04.txt
#   inflating: /content/data/MIR-1K/Lyrics/khair_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_4_06.txt
#   inflating: /content/data/MIR-1K/Lyrics/khair_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_04.txt
#   inflating: /content/data/MIR-1K/Lyrics/khair_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/khair_6_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_01.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_1_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_2_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_09.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_3_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_5_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_03.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_6_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_05.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_6_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_6_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_10.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_7_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_7_12.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_7_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_03.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_8_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_05.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_8_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_10.txt
#   inflating: /content/data/MIR-1K/Lyrics/leon_8_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_8_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/leon_9_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_1_07.txt
#   inflating: /content/data/MIR-1K/Lyrics/stool_1_08.txt
#   inflating: /content/data/MIR-1K/Lyrics/stool_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/stool_5_07.txt
#   inflating: /content/data/MIR-1K/Lyrics/stool_5_08.txt
#   inflating: /content/data/MIR-1K/Lyrics/tammy_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/tammy_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_4_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/titon_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_15.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_1_16.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_13.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_14.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_2_15.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_3_12.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_10.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_4_11.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_01.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_02.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_03.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_04.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_05.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_06.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_07.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_08.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_09.txt
#  extracting: /content/data/MIR-1K/Lyrics/yifen_5_10.txt
#   inflating: /content/data/MIR-1K/Lyrics/yifen_5_11.txt
#    creating: /content/data/MIR-1K/LyricsWav/
#   inflating: /content/data/MIR-1K/LyricsWav/ABJones_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ABJones_2_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ABJones_3_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ABJones_4_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ABJones_5_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_10_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_11_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_12_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_13_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_14_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_15_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_16_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_2_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_3_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_4_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_5_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_6_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_7_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_8_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/amy_9_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/Ani_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/Ani_2_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/Ani_3_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/Ani_4_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/Ani_5_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/annar_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/annar_2_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/annar_3_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/annar_4_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/annar_5_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ariel_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ariel_2_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ariel_3_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ariel_4_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/ariel_5_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/bobon_1_lyrics.wav
#   inflating: /content/data/MIR-1K/LyricsWav/bobon_2_lyrics.wav
# ...
#   inflating: /content/data/MIR-1K/Wavfile/khair_5_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_5_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_5_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_5_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_5_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/khair_6_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_1_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_2_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_3_13.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_4_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_5_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_6_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_7_13.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_8_13.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/leon_9_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_1_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_2_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_3_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_4_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/stool_5_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/tammy_1_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_1_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_2_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_3_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_4_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/titon_5_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_13.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_14.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_15.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_1_16.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_13.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_14.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_2_15.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_3_12.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_4_11.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_01.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_02.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_03.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_04.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_05.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_06.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_07.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_08.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_09.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_10.wav
#   inflating: /content/data/MIR-1K/Wavfile/yifen_5_11.wav
